# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/BLR-DEL/2021-11-26?sort=duration_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        
dep_time
# Out:
# ['13:20',
#  '10:25',
#  '17:45',
#  '21:10',
#  '00:10',
#  '08:00',
#  '11:30',
#  '07:00',
#  '06:15',
#  '21:55',
#  '19:40',
#  '11:20',
#  '14:00',
#  '09:30',
#  '19:05',
#  '05:55',
#  '06:10',
#  '17:50',
#  '21:00',
#  '07:40',
#  '22:10',
#  '00:45',
#  '16:30',
#  '06:40',
#  '09:45',
#  '19:15',
#  '11:55',
#  '23:35',
#  '17:50',
#  '04:40',
#  '22:10',
#  '21:00',
#  '20:10',
#  '07:50',
#  '18:25',
#  '15:45',
#  '15:45',
#  '18:50',
#  '07:10',
#  '12:20',
#  '17:00',
#  '07:30',
#  '17:00',
#  '20:45',
#  '18:45',
#  '19:55',
#  '11:30',
#  '13:05',
#  '15:20',
#  '08:55',
#  '18:55',
#  '14:50',
#  '16:15',
#  '05:25',
#  '06:45',
#  '12:05',
#  '08:30',
#  '18:15',
#  '06:10',
#  '18:25',
#  '20:00',
#  '18:55',
#  '06:40',
#  '18:45',
#  '16:20',
#  '18:50',
#  '11:45',
#  '10:15',
#  '08:10',
#  '05:40',
#  '05:45',
#  '07:05',
#  '08:55',
#  '07:00',
#  '18:25',
#  '13:05',
#  '13:50',
#  '07:05',
#  '18:40',
#  '17:30',
#  '09:05',
#  '13:00',
#  '09:20',
# ...

# %%
arr_time = []

arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
arr_time
# Out:
# ['15:50',
#  '13:00',
#  '20:20',
#  '23:45',
#  '02:50',
#  '10:40',
#  '14:10',
#  '09:40',
#  '08:55',
#  '00:35',
#  '22:25',
#  '14:05',
#  '16:45',
#  '12:15',
#  '21:50',
#  '08:40',
#  '08:55',
#  '20:35',
#  '23:50',
#  '10:30',
#  '01:00',
#  '03:35',
#  '19:20',
#  '09:30',
#  '12:40',
#  '22:10',
#  '14:50',
#  '02:30',
#  '20:45',
#  '07:35',
#  '01:05',
#  '23:55',
#  '23:10',
#  '10:50',
#  '23:00',
#  '20:20',
#  '20:20',
#  '23:30',
#  '11:55',
#  '17:05',
#  '21:50',
#  '12:20',
#  '21:50',
#  '01:45',
#  '23:45',
#  '00:55',
#  '16:30',
#  '18:10',
#  '20:25',
#  '14:05',
#  '00:10',
#  '20:10',
#  '21:40',
#  '10:55',
#  '12:15',
#  '17:35',
#  '14:05',
#  '23:55',
#  '11:55',
#  '00:10',
#  '02:00',
#  '00:55',
#  '12:40',
#  '00:45',
#  '22:25',
#  '01:00',
#  '18:00',
#  '16:30',
#  '14:30',
#  '12:00',
#  '12:10',
#  '13:30',
#  '15:20',
#  '13:30',
#  '00:55',
#  '19:55',
#  '20:40',
#  '14:00',
#  '01:40',
#  '00:35',
#  '16:15',
#  '20:10',
#  '16:30',
# ...

# %%
print(len(arr_time))
# Out:
# 145

# %%
depp = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
depp
# Out:
# ['BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
# ...

# %%
print(len(depp))
# Out:
# 145

# %%
arr = []

ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arr.append('NAN')
    else:
        arr.append(i.text)
        
arr
# Out:
# ['DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
# ...

# %%
print(len(arr))
# Out:
# 145

# %%
stp = []

st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        
stp
# Out:
# ['direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  '1 stop',
#  '1 stop',
#  'direct',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  'direct',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
# ...

# %%
print(len(stp))
# Out:
# 145

# %%
dur = []

du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
dur
# Out:
# ['2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '3h 00m',
#  '3h 00m',
#  '4h 35m',
#  '4h 35m',
#  '4h 35m',
#  '4h 40m',
#  '4h 45m',
#  '4h 45m',
#  '4h 50m',
#  '4h 50m',
#  '4h 50m',
#  '5h 00m',
#  '5h 00m',
#  '5h 00m',
#  '5h 00m',
#  '5h 05m',
#  '5h 05m',
#  '5h 10m',
#  '5h 15m',
#  '5h 20m',
#  '5h 25m',
#  '5h 30m',
#  '5h 30m',
#  '5h 30m',
#  '5h 35m',
#  '5h 40m',
#  '5h 45m',
#  '5h 45m',
#  '6h 00m',
#  '6h 00m',
#  '6h 00m',
#  '6h 00m',
#  '6h 05m',
#  '6h 10m',
#  '6h 15m',
#  '6h 15m',
#  '6h 20m',
#  '6h 20m',
#  '6h 25m',
#  '6h 25m',
#  '6h 25m',
#  '6h 30m',
#  '6h 30m',
#  '6h 50m',
# ...

# %%
print(len(dur))
# Out:
# 145

# %%
pric = []

pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)
        
pric
# Out:
# ['₹ 7,986',
#  '₹ 7,205',
#  '₹ 7,238',
#  '₹ 7,343',
#  '₹ 3,500',
#  '₹ 7,238',
#  '₹ 7,238',
#  '₹ 7,238',
#  '₹ 7,461',
#  '₹ 7,488',
#  '₹ 7,238',
#  '₹ 7,461',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,488',
#  '₹ 7,488',
#  '₹ 7,595',
#  '₹ 7,595',
#  '₹ 3,500',
#  '₹ 3,500',
#  '₹ 7,461',
#  '₹ 7,461',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,238',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 7,595',
#  '₹ 7,468',
#  '₹ 7,468',
#  '₹ 10,538',
#  '₹ 17,733',
#  '₹ 17,815',
#  '₹ 7,454',
#  '₹ 9,988',
#  '₹ 16,675',
#  '₹ 7,454',
#  '₹ 7,454',
#  '₹ 7,487',
#  '₹ 7,458',
#  '₹ 8,114',
#  '₹ 10,538',
#  '₹ 12,487',
#  '₹ 7,468',
#  '₹ 13,753',
#  '₹ 12,073',
#  '₹ 10,428',
#  '₹ 13,034',
#  '₹ 13,769',
#  '₹ 8,534',
#  '₹ 10,210',
#  '₹ 32,517',
#  '₹ 10,538',
#  '₹ 13,207',
#  '₹ 9,988',
#  '₹ 10,538',
#  '₹ 6,033',
#  '₹ 10,428',
#  '₹ 10,428',
#  '₹ 11,143',
#  '₹ 7,468',
#  '₹ 7,458',
#  '₹ 7,690',
#  '₹ 8,760',
#  '₹ 7,407',
#  '₹ 7,458',
# ...

# %%
print(len(pric))
# Out:
# 145

# %%
Flight = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arr, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight
# Out:
#         Price    Stops Duration           Departure                 Arrival  \
# 0     ₹ 7,986   direct   2h 30m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 1     ₹ 7,205   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 2     ₹ 7,238   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 3     ₹ 7,343   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 4     ₹ 3,500   direct   2h 40m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# ..        ...      ...      ...                 ...                     ...
# 140   ₹ 7,486   1 stop  11h 10m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 141  ₹ 11,385   1 stop  11h 10m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 142   ₹ 7,485  2 stops  11h 15m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 143   ₹ 7,486   1 stop  11h 15m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 144   ₹ 7,637   1 stop  11h 15m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
#
#     DepartureTime ArrivalTime
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/BLR-LHR,GVA/2021-11-26?sort=bestflight_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        
dep_time
# Out:
# ['07:30',
#  '02:15',
#  '02:15',
#  '09:45',
#  '08:00',
#  '21:40',
#  '19:10',
#  '21:00',
#  '17:50',
#  '13:20',
#  '22:00',
#  '22:40',
#  '22:00',
#  '20:00',
#  '07:00',
#  '19:40',
#  '23:35',
#  '20:10',
#  '07:30',
#  '07:30',
#  '03:35',
#  '03:35',
#  '03:35',
#  '07:30',
#  '07:30',
#  '22:40',
#  '21:40',
#  '19:55',
#  '18:55',
#  '18:25',
#  '03:35',
#  '03:35',
#  '03:35',
#  '21:10',
#  '19:40',
#  '22:40',
#  '06:45',
#  '09:30',
#  '10:25',
#  '06:10',
#  '21:00',
#  '21:00',
#  '09:30',
#  '07:30',
#  '11:20',
#  '11:55',
#  '14:00',
#  '18:50',
#  '11:30',
#  '18:50',
#  '03:35',
#  '03:35',
#  '12:40',
#  '09:30',
#  '08:30',
#  '06:40',
#  '07:30',
#  '07:30',
#  '06:40',
#  '03:35',
#  '03:35',
#  '03:35',
#  '11:30',
#  '07:00',
#  '19:35',
#  '03:35',
#  '02:15',
#  '21:10',
#  '10:25',
#  '04:20',
#  '10:25',
#  '04:20',
#  '04:20',
#  '04:20',
#  '04:20',
#  '03:45',
#  '03:45',
#  '10:25',
#  '17:15',
#  '22:55',
#  '17:15',
#  '10:00',
#  '22:40',
# ...

# %%
arr_time = []

arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
arr_time
# Out:
# ['13:05',
#  '10:45',
#  '12:15',
#  '17:45',
#  '17:45',
#  '07:15',
#  '11:30',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:30',
#  '11:30',
#  '07:15',
#  '11:30',
#  '17:45',
#  '11:05',
#  '11:05',
#  '11:05',
#  '23:45',
#  '20:55',
#  '14:15',
#  '17:30',
#  '22:10',
#  '18:05',
#  '21:55',
#  '07:15',
#  '09:00',
#  '09:00',
#  '09:00',
#  '09:00',
#  '10:45',
#  '14:45',
#  '16:45',
#  '07:40',
#  '07:40',
#  '09:00',
#  '11:30',
#  '11:30',
#  '11:05',
#  '11:05',
#  '16:40',
#  '18:40',
#  '07:15',
#  '19:40',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:05',
#  '07:15',
#  '11:30',
#  '08:10',
#  '18:25',
#  '07:15',
#  '09:00',
#  '09:00',
#  '09:00',
#  '09:35',
#  '12:25',
#  '17:45',
#  '22:15',
#  '07:45',
#  '08:45',
#  '07:40',
#  '07:40',
#  '09:00',
#  '13:00',
#  '18:10',
#  '08:00',
#  '18:20',
#  '13:50',
#  '20:00',
#  '16:10',
#  '12:45',
#  '18:20',
#  '20:00',
#  '12:20',
#  '13:20',
#  '14:55',
#  '21:40',
#  '15:45',
#  '18:05',
#  '14:55',
#  '10:45',
# ...

# %%
depp = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
depp
# Out:
# ['BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
#  'BLR Bengaluru Intl',
# ...

# %%
arr = []

ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arr.append('NAN')
    else:
        arr.append(i.text)
        
arr
# Out:
# ['LHR Heathrow',
#  'LHR Heathrow',
#  'GVA Geneve-Cointrin',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'GVA Geneve-Cointrin',
#  'GVA Geneve-Cointrin',
#  'LHR Heathrow',
#  'GVA Geneve-Cointrin',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
#  'LHR Heathrow',
# ...

# %%
stp = []

st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        
stp
# Out:
# ['direct',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '2 stops',
#  '2 stops',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '2 stops',
#  '1 stop',
#  '2 stops',
#  '1 stop',
#  '2 stops',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '2 stops',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '2 stops',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
# ...

# %%
dur = []

du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
dur
# Out:
# ['11h 05m',
#  '14h 00m',
#  '14h 30m',
#  '13h 30m',
#  '15h 15m',
#  '15h 05m',
#  '21h 50m',
#  '19h 35m',
#  '22h 45m',
#  '27h 15m',
#  '19h 00m',
#  '18h 20m',
#  '14h 45m',
#  '21h 00m',
#  '16h 15m',
#  '20h 55m',
#  '17h 00m',
#  '20h 25m',
#  '20h 45m',
#  '17h 55m',
#  '15h 10m',
#  '18h 25m',
#  '23h 05m',
#  '15h 05m',
#  '18h 55m',
#  '14h 05m',
#  '16h 50m',
#  '18h 35m',
#  '19h 35m',
#  '20h 05m',
#  '12h 40m',
#  '16h 40m',
#  '18h 40m',
#  '16h 00m',
#  '17h 30m',
#  '15h 50m',
#  '34h 15m',
#  '31h 30m',
#  '30h 10m',
#  '34h 25m',
#  '24h 10m',
#  '26h 10m',
#  '27h 15m',
#  '16h 40m',
#  '29h 15m',
#  '28h 40m',
#  '26h 35m',
#  '21h 45m',
#  '25h 15m',
#  '22h 10m',
#  '33h 05m',
#  '19h 20m',
#  '24h 05m',
#  '29h 00m',
#  '30h 00m',
#  '31h 50m',
#  '30h 35m',
#  '33h 25m',
#  '16h 35m',
#  '24h 10m',
#  '33h 40m',
#  '34h 40m',
#  '25h 40m',
#  '30h 10m',
#  '18h 55m',
#  '14h 55m',
#  '21h 25m',
#  '16h 20m',
#  '13h 25m',
#  '15h 00m',
#  '15h 05m',
# ...

# %%
pric = []

pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)
        
pric
# Out:
# ['₹ 31,218',
#  '₹ 26,597',
#  '₹ 33,488',
#  '₹ 38,531',
#  '₹ 38,531',
#  '₹ 38,878',
#  '₹ 30,819',
#  '₹ 33,814',
#  '₹ 33,814',
#  '₹ 33,814',
#  '₹ 34,442',
#  '₹ 34,790',
#  '₹ 38,791',
#  '₹ 41,748',
#  '₹ 41,835',
#  '₹ 42,270',
#  '₹ 42,705',
#  '₹ 42,705',
#  '₹ 43,001',
#  '₹ 43,356',
#  '₹ 43,362',
#  '₹ 43,473',
#  '₹ 44,578',
#  '₹ 45,016',
#  '₹ 46,341',
#  '₹ 46,383',
#  '₹ 46,444',
#  '₹ 46,444',
#  '₹ 46,444',
#  '₹ 46,444',
#  '₹ 47,033',
#  '₹ 47,033',
#  '₹ 47,225',
#  '₹ 50,684',
#  '₹ 50,684',
#  '₹ 51,716',
#  '₹ 30,819',
#  '₹ 34,007',
#  '₹ 36,278',
#  '₹ 36,278',
#  '₹ 37,293',
#  '₹ 37,293',
#  '₹ 38,269',
#  '₹ 38,975',
#  '₹ 42,357',
#  '₹ 42,705',
#  '₹ 43,139',
#  '₹ 43,720',
#  '₹ 44,531',
#  '₹ 44,721',
#  '₹ 45,029',
#  '₹ 45,031',
#  '₹ 45,314',
#  '₹ 46,444',
#  '₹ 46,444',
#  '₹ 46,444',
#  '₹ 47,423',
#  '₹ 47,423',
#  '₹ 48,044',
#  '₹ 48,330',
#  '₹ 49,180',
#  '₹ 49,180',
#  '₹ 50,684',
#  '₹ 50,684',
#  '₹ 52,351',
#  '₹ 52,708',
# ...

# %%
Flight1 = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arr, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight1
# Out:
#          Price    Stops Duration           Departure              Arrival  \
# 0     ₹ 31,218   direct  11h 05m  BLR Bengaluru Intl         LHR Heathrow
# 1     ₹ 26,597   1 stop  14h 00m  BLR Bengaluru Intl         LHR Heathrow
# 2     ₹ 33,488   1 stop  14h 30m  BLR Bengaluru Intl  GVA Geneve-Cointrin
# 3     ₹ 38,531   1 stop  13h 30m  BLR Bengaluru Intl         LHR Heathrow
# 4     ₹ 38,531   1 stop  15h 15m  BLR Bengaluru Intl         LHR Heathrow
# ..         ...      ...      ...                 ...                  ...
# 185  ₹ 112,569   1 stop  32h 05m  BLR Bengaluru Intl         LHR Heathrow
# 186  ₹ 135,518   1 stop  33h 50m  BLR Bengaluru Intl         LHR Heathrow
# 187  ₹ 184,521  2 stops  20h 13m  BLR Bengaluru Intl           GVA Genève
# 188  ₹ 198,156   1 stop  14h 00m  BLR Bengaluru Intl         LHR Heathrow
# 189  ₹ 342,188  2 stops  20h 00m  BLR Bengaluru Intl         LHR Heathrow
#
#     DepartureTime ArrivalTime
# 0           07:30       13:05
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/LHR,GVA-BLR,MAA/2021-11-26?sort=price_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []
arr_time = []
depp = []
arrp = []
stp = []
dur = []
pric = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        



arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
        
        


dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
        


ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arrp.append('NAN')
    else:
        arrp.append(i.text)
        


st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        


du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
        


pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)

# %%
print(len(pric),len(stp),len(dur),len(arrp),len(dep_time),len(arr_time))
# Out:
# 310 310 310 310 310 310

# %%
Flight3 = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arrp, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight3
# Out:
#            Price    Stops Duration            Departure             Arrival  \
# 0       ₹ 22,066  3 stops  31h 20m  GVA Geneve-Cointrin  BLR Bengaluru Intl
# 1       ₹ 23,403  3 stops  42h 40m  GVA Geneve-Cointrin  BLR Bengaluru Intl
# 2       ₹ 23,968  3 stops  30h 50m  GVA Geneve-Cointrin  BLR Bengaluru Intl
# 3       ₹ 24,158  3 stops  49h 35m  GVA Geneve-Cointrin  BLR Bengaluru Intl
# 4       ₹ 24,367  3 stops  37h 45m  GVA Geneve-Cointrin  BLR Bengaluru Intl
# ..           ...      ...      ...                  ...                 ...
# 305    ₹ 349,762  2 stops  22h 20m         LHR Heathrow  BLR Bengaluru Intl
# 306    ₹ 349,762  2 stops  22h 35m         LHR Heathrow  BLR Bengaluru Intl
# 307    ₹ 470,552  2 stops  19h 03m           GVA Genève         MAA Chennai
# 308    ₹ 481,191  2 stops  14h 25m         LHR Heathrow  BLR Bengaluru Intl
# 309  ₹ 1,113,208  2 stops  51h 45m         LHR Heathrow  BLR Bengaluru Intl
#
#     DepartureTime ArrivalTime
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/DEL,BOM-CCU,CJB/2021-11-26?sort=price_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []
arr_time = []
depp = []
arrp = []
stp = []
dur = []
pric = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        



arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
        
        


dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
        


ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arrp.append('NAN')
    else:
        arrp.append(i.text)
        


st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        


du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
        


pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)

# %%
print(len(pric),len(stp),len(dur),len(arrp),len(dep_time),len(arr_time))
# Out:
# 351 351 351 351 351 351

# %%
Flight4 = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arrp, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight4
# Out:
#          Price    Stops Duration                     Departure  \
# 0      ₹ 2,965   direct   2h 10m        DEL Indira Gandhi Intl
# 1      ₹ 2,965   direct   2h 10m        DEL Indira Gandhi Intl
# 2      ₹ 2,965   direct   2h 20m        DEL Indira Gandhi Intl
# 3      ₹ 3,319   direct   1h 50m  BOM Chhatrapati Shivaji Intl
# 4      ₹ 4,007   1 stop   3h 05m  BOM Chhatrapati Shivaji Intl
# ..         ...      ...      ...                           ...
# 346  ₹ 110,765  2 stops  24h 40m        DEL Indira Gandhi Intl
# 347  ₹ 115,963  2 stops  30h 05m        DEL Indira Gandhi Intl
# 348  ₹ 117,443  2 stops  28h 45m  BOM Chhatrapati Shivaji Intl
# 349  ₹ 118,982  2 stops  28h 05m  BOM Chhatrapati Shivaji Intl
# 350  ₹ 118,982  2 stops  29h 10m  BOM Chhatrapati Shivaji Intl
#
#                    Arrival DepartureTime ArrivalTime
# 0    CCU Netaji S. Chandra         05:00       07:10
# 1    CCU Netaji S. Chandra         05:50       08:00
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/JAI,YTO,DEL-DEL,DRT,CCU/2021-11-26?sort=price_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []
arr_time = []
depp = []
arrp = []
stp = []
dur = []
pric = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        



arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
        
        


dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
        


ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arrp.append('NAN')
    else:
        arrp.append(i.text)
        


st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        


du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
        


pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)

# %%
print(len(pric),len(stp),len(dur),len(arrp),len(dep_time),len(arr_time))
# Out:
# 373 373 373 373 373 373

# %%
Flight5 = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arrp, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight5
# Out:
#          Price    Stops Duration               Departure  \
# 0      ₹ 2,965   direct   2h 10m  DEL Indira Gandhi Intl
# 1      ₹ 2,965   direct   2h 10m  DEL Indira Gandhi Intl
# 2      ₹ 2,965   direct   2h 20m  DEL Indira Gandhi Intl
# 3      ₹ 4,347   direct   2h 05m  DEL Indira Gandhi Intl
# 4      ₹ 4,347   direct   2h 10m  DEL Indira Gandhi Intl
# ..         ...      ...      ...                     ...
# 368  ₹ 479,899  2 stops  22h 30m        YYZ Pearson Intl
# 369  ₹ 479,899  2 stops  23h 30m        YYZ Pearson Intl
# 370  ₹ 479,899  2 stops  25h 30m        YYZ Pearson Intl
# 371  ₹ 479,899  2 stops  26h 30m        YYZ Pearson Intl
# 372  ₹ 539,365  2 stops  23h 31m        YYZ Pearson Intl
#
#                    Arrival DepartureTime ArrivalTime
# 0    CCU Netaji S. Chandra         05:50       08:00
# 1    CCU Netaji S. Chandra         05:00       07:10
# 2    CCU Netaji S. Chandra         19:25       21:45
# 3    CCU Netaji S. Chandra         20:15       22:20
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.kayak.co.in/flights/LHR,GVA,USM-MAA,DEL,LON/2021-11-26?sort=price_a"
driver.get(url)
time.sleep(6)

# %%
dep_time = []
arr_time = []
depp = []
arrp = []
stp = []
dur = []
pric = []

dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[1]/span")
for i in dep:
    if i.text is None:
        dep_time.append('NAN')
    else:
        dep_time.append(i.text)
        



arr = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div/span[3]/span")
for i in arr:
    if i.text is None:
        arr_time.append('NAN')
    else:
        arr_time.append(i.text)
        
        
        


dep = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[1]/span")
for i in dep:
    if i.text is None:
        depp.append('NAN')
    else:
        depp.append(i.text)
        
        


ar = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[2]/div[2]/div[2]/span")
for i in ar:
    if i.text is None:
        arrp.append('NAN')
    else:
        arrp.append(i.text)
        


st = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[3]/div[1]/span[1]")
for i in st:
    if i.text is None:
        stp.append('NAN')
    else:
        stp.append(i.text)
        


du = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[1]/div[2]/div/ol/li/div/div/div[4]/div[1]")
for i in du:
    if i.text is None:
        dur.append('NAN')
    else:
        dur.append(i.text)
        
        


pri = driver.find_elements_by_xpath("//div[@class= 'resultWrapper']/div[2]/div/div[2]/div/div[2]/div[1]/div/div/div/a/span/span")
for i in pri:
    if i.text is None:
        pric.append('NAN')
    else:
        pric.append(i.text)

# %%
print(len(pric),len(stp),len(dur),len(arrp),len(dep_time),len(arr_time))
# Out:
# 807 807 807 807 807 807

# %%
Flight6 = pd.DataFrame({'Price': pric,'Stops':stp, 'Duration':dur,'Departure': depp,'Arrival':arrp, 'DepartureTime':dep_time, 'ArrivalTime': arr_time})
Flight6
# Out:
#            Price    Stops Duration            Departure  \
# 0        ₹ 2,118   direct   1h 35m  GVA Geneve-Cointrin
# 1        ₹ 2,282   direct   1h 45m  GVA Geneve-Cointrin
# 2        ₹ 2,486   direct   1h 30m  GVA Geneve-Cointrin
# 3        ₹ 2,498   1 stop  22h 05m  GVA Geneve-Cointrin
# 4        ₹ 3,032   direct   1h 35m  GVA Geneve-Cointrin
# ..           ...      ...      ...                  ...
# 802    ₹ 939,788  2 stops  31h 20m  GVA Geneve-Cointrin
# 803    ₹ 940,775  2 stops  32h 25m  GVA Geneve-Cointrin
# 804    ₹ 943,223  2 stops  32h 45m  GVA Geneve-Cointrin
# 805  ₹ 1,041,857   1 stop  30h 00m         LHR Heathrow
# 806  ₹ 1,074,067   1 stop  28h 10m         LHR Heathrow
#
#                     Arrival DepartureTime ArrivalTime
# 0               LGW Gatwick         07:00       07:35
# 1                 LTN Luton         20:15       21:00
# 2               LGW Gatwick         21:35       22:05
# 3              STN Stansted         21:25       18:30
# ...

# %%
r1 = pd.concat([Flight,Flight1], axis = 0)
r1
# Out:
#          Price    Stops Duration           Departure                 Arrival  \
# 0      ₹ 7,986   direct   2h 30m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 1      ₹ 7,205   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 2      ₹ 7,238   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 3      ₹ 7,343   direct   2h 35m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# 4      ₹ 3,500   direct   2h 40m  BLR Bengaluru Intl  DEL Indira Gandhi Intl
# ..         ...      ...      ...                 ...                     ...
# 185  ₹ 112,569   1 stop  32h 05m  BLR Bengaluru Intl            LHR Heathrow
# 186  ₹ 135,518   1 stop  33h 50m  BLR Bengaluru Intl            LHR Heathrow
# 187  ₹ 184,521  2 stops  20h 13m  BLR Bengaluru Intl              GVA Genève
# 188  ₹ 198,156   1 stop  14h 00m  BLR Bengaluru Intl            LHR Heathrow
# 189  ₹ 342,188  2 stops  20h 00m  BLR Bengaluru Intl            LHR Heathrow
#
#     DepartureTime ArrivalTime
# ...

# %%
r2 =  pd.concat([r1,Flight3], axis = 0)
r3 =  pd.concat([r2,Flight4], axis = 0)
r4 =  pd.concat([r3,Flight5], axis = 0)
res =  pd.concat([r4,Flight6], axis = 0)

# %%
res
# Out:
#            Price    Stops Duration            Departure  \
# 0        ₹ 7,986   direct   2h 30m   BLR Bengaluru Intl
# 1        ₹ 7,205   direct   2h 35m   BLR Bengaluru Intl
# 2        ₹ 7,238   direct   2h 35m   BLR Bengaluru Intl
# 3        ₹ 7,343   direct   2h 35m   BLR Bengaluru Intl
# 4        ₹ 3,500   direct   2h 40m   BLR Bengaluru Intl
# ..           ...      ...      ...                  ...
# 802    ₹ 939,788  2 stops  31h 20m  GVA Geneve-Cointrin
# 803    ₹ 940,775  2 stops  32h 25m  GVA Geneve-Cointrin
# 804    ₹ 943,223  2 stops  32h 45m  GVA Geneve-Cointrin
# 805  ₹ 1,041,857   1 stop  30h 00m         LHR Heathrow
# 806  ₹ 1,074,067   1 stop  28h 10m         LHR Heathrow
#
#                     Arrival DepartureTime ArrivalTime
# 0    DEL Indira Gandhi Intl         13:20       15:50
# 1    DEL Indira Gandhi Intl         10:25       13:00
# 2    DEL Indira Gandhi Intl         17:45       20:20
# 3    DEL Indira Gandhi Intl         21:10       23:45
# ...

# %%
res.to_excel("flip_datas.xlsx", index = False)
